# %%
print('Shri hanumataye namah')
# Out:
# Shri hanumataye namah

# %%
2+2
# Out:
# 4

# %% [markdown]
# Clinical Audit LSCS

# %%
df = pd.read_csv("Book1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5364/239648207.py in <module>
# ----> 1 df = pd.read_csv("Book1.csv")
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv("Book1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5364/239648207.py in <module>
# ----> 1 df = pd.read_csv("Book1.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("Book1.csv")

# %%
def()
# Out:
#   File "C:\Users\Acer\AppData\Local\Temp/ipykernel_5364/3088396893.py", line 1
#     def()
#        ^
# SyntaxError: invalid syntax

# %%
df.head(23)
# Out:
#     Unnamed: 0  Patient regn. No. Name of the surgery Consent for surgeries  \
# 0            1              22695                CABG                   yes
# 1            2              22723             L.S.C.S                   yes
# 2            3              22790             L.S.C.S                   yes
# 3            4              22798                CABG                   yes
# 4            5              22870             L.S.C.S                   yes
# 5            6              22974             L.S.C.S                   yes
# 6            7              22059                CABG                   yes
# 7            8              23020           Laprotomy                   yes
# 8            9              23137             L.S.C.S                   yes
# 9           10              23150             L.S.C.S                   yes
# 10          11              23178                CABG                   yes
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.Target.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
![](Balaji.png)
# Out:
# '[]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![](Balaji.png)
